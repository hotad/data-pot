-- %% [markdown]
-- Input dataset

-- %%
use mydb;


CREATE TABLE visitor_details (
    name        VARCHAR(50),
    address     VARCHAR(100),
    email       VARCHAR(100),
    floor       INT,
    resources   VARCHAR(50)
);

INSERT INTO visitor_details
    (name, address, email, floor, resources)
VALUES
    ('A', 'Bangalore', 'A@gmail.com', 1, 'CPU'),
    ('A', 'Bangalore', 'A1@gmail.com', 1, 'CPU'),
    ('A', 'Bangalore', 'A2@gmail.com', 2, 'DESKTOP'),
    ('B', 'Bangalore', 'B@gmail.com', 2, 'DESKTOP'),
    ('B', 'Bangalore', 'B1@gmail.com', 2, 'DESKTOP'),
    ('B', 'Bangalore', 'B2@gmail.com', 1, 'MONITOR');

    select * from mydb.visitor_details;

-- %% [markdown]
-- Output Dataset

-- %%
use mydb ;
CREATE TABLE visitor_summary (
    name               VARCHAR(50),
    total_visits       INT,
    most_visited_floor INT,
    resources_used     VARCHAR(200)
);

INSERT INTO visitor_summary
    (name, total_visits, most_visited_floor, resources_used)
VALUES
    ('A', 3, 1, 'CPU,DESKTOP'),
    ('B', 3, 2, 'DESKTOP,MONITOR');
